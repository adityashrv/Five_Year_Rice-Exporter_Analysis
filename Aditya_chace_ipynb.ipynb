# %%
# Libraries import    
import pandas as pd
import numpy as np

# %%
# importing data of year 2018

df1= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2018.xlsx',sheet_name='Trade Atlas Records - Jan')
df2= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2018.xlsx',sheet_name='Trade Atlas Records - Feb')
df3= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2018.xlsx',sheet_name='Trade Atlas Records - Mar')
df4= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2018.xlsx',sheet_name='Trade Atlas Records - Apr')
df5= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2018.xlsx',sheet_name='Trade Atlas Records - May')
df6= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2018.xlsx',sheet_name='Trade Atlas Records - Jun')
df7= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2018.xlsx',sheet_name='Trade Atlas Records - Jul')
df8= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2018.xlsx',sheet_name='Trade Atlas Records - Aug')
df9= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2018.xlsx',sheet_name='Trade Atlas Records - Sep')
df10= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2018.xlsx',sheet_name='Trade Atlas Records - Oct')
df11= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2018.xlsx',sheet_name='Trade Atlas Records - Nov')
df12= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2018.xlsx',sheet_name='Trade Atlas Records - Dec')

# %%
# merge whole data of year 2018 and creating one dataframe

from functools import reduce  # import reduce

dfs2018 = [df1, df2, df3, df4,df5, df6, df7, df8, df9, df10, df11, df12]
df_2018 = reduce(lambda left,right: pd.merge(left,right,how='outer'), dfs2018)
df_2018.shape
# Out:
# (65277, 46)

# %%
# importing data of year 2019

bdf1= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2019.xlsx',sheet_name='Trade Atlas Records - Jan')
bdf2= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2019.xlsx',sheet_name='Trade Atlas Records - Feb')
bdf3= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2019.xlsx',sheet_name='Trade Atlas Records - Mar')
bdf4= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2019.xlsx',sheet_name='Trade Atlas Records - Apr')
bdf5= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2019.xlsx',sheet_name='Trade Atlas Records - May')
bdf6= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2019.xlsx',sheet_name='Trade Atlas Records - Jun')
bdf7= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2019.xlsx',sheet_name='Trade Atlas Records - Jul')
bdf8= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2019.xlsx',sheet_name='Trade Atlas Records - Aug')
bdf9= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2019.xlsx',sheet_name='Trade Atlas Records - Sep')
bdf10= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2019.xlsx',sheet_name='Trade Atlas Records - Oct')
bdf11= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2019.xlsx',sheet_name='Trade Atlas Records - Nov')
bdf12= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2019.xlsx',sheet_name='Trade Atlas Records - Dec')

# %%
# merge whole data of year 2019 and creating one dataframe

dfs2019 = [bdf1, bdf2, bdf3, bdf4,bdf5, bdf6, bdf7, bdf8, bdf9, bdf10, bdf11, bdf12]
df_2019 = reduce(lambda left,right: pd.merge(left,right,how='outer'), dfs2019)
df_2019.shape
# Out:
# C:\Users\Aditya\AppData\Local\Temp\ipykernel_20516\1564359401.py:4: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation.
#   df_2019 = reduce(lambda left,right: pd.merge(left,right,how='outer'), dfs2019)
# C:\Users\Aditya\AppData\Local\Temp\ipykernel_20516\1564359401.py:4: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation.
#   df_2019 = reduce(lambda left,right: pd.merge(left,right,how='outer'), dfs2019)
# C:\Users\Aditya\AppData\Local\Temp\ipykernel_20516\1564359401.py:4: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation.
#   df_2019 = reduce(lambda left,right: pd.merge(left,right,how='outer'), dfs2019)
# (65646, 46)

# %%
# importing data of year 2020

cdf1= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2020.xlsx',sheet_name='Jan')
cdf2= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2020.xlsx',sheet_name='Feb')
cdf3= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2020.xlsx',sheet_name='March')
cdf4= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2020.xlsx',sheet_name='April')
cdf5= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2020.xlsx',sheet_name='May')
cdf6= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2020.xlsx',sheet_name='June')
cdf7= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2020.xlsx',sheet_name='July')
cdf8= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2020.xlsx',sheet_name='August')
cdf9= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2020.xlsx',sheet_name='Sept')
cdf10= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2020.xlsx',sheet_name='October')
cdf11= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2020.xlsx',sheet_name='Nov')
cdf12= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2020.xlsx',sheet_name='Dec')

# %%
# merge whole data of year 2020 and creating one dataframe

dfs2020 = [cdf1, cdf2, cdf3, cdf4,cdf5, cdf6, cdf7, cdf8, cdf9, cdf10, cdf11, cdf12]
df_2020 = reduce(lambda left,right: pd.merge(left,right,how='outer'), dfs2020)
df_2020.shape
# Out:
# (89226, 46)

# %%
# importing data of year 2021

ddf1= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2021.xlsx',sheet_name='January')
ddf2= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2021.xlsx',sheet_name='February')
ddf3= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2021.xlsx',sheet_name='March')
ddf4= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2021.xlsx',sheet_name='April')
ddf5= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2021.xlsx',sheet_name='May data')
ddf6= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2021.xlsx',sheet_name='June')
ddf7= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2021.xlsx',sheet_name='July')
ddf8= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2021.xlsx',sheet_name='August')
ddf9= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2021.xlsx',sheet_name='Sept')
ddf10= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2021.xlsx',sheet_name='October')
ddf11= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2021.xlsx',sheet_name='November')
ddf12= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2021.xlsx',sheet_name='Dec 1')
ddf13= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2021.xlsx',sheet_name='Dec 2')

# %%
# merge whole data of year 2021 and creating one dataframe

dfs2021 = [ddf1, ddf2, ddf3, ddf4,ddf5, ddf6, ddf7, ddf8, ddf9, ddf10, ddf11, ddf12, ddf13]
df_2021 = reduce(lambda left,right: pd.merge(left,right,how='outer'), dfs2021)
df_2021.shape
# Out:
# C:\Users\Aditya\AppData\Local\Temp\ipykernel_20516\2358754847.py:4: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation.
#   df_2021 = reduce(lambda left,right: pd.merge(left,right,how='outer'), dfs2021)
# C:\Users\Aditya\AppData\Local\Temp\ipykernel_20516\2358754847.py:4: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation.
#   df_2021 = reduce(lambda left,right: pd.merge(left,right,how='outer'), dfs2021)
# C:\Users\Aditya\AppData\Local\Temp\ipykernel_20516\2358754847.py:4: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation.
#   df_2021 = reduce(lambda left,right: pd.merge(left,right,how='outer'), dfs2021)
# ...

# %%
# importing data of year 2022

edf1= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2022.xlsx',sheet_name='Jan')
edf2= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2022.xlsx',sheet_name='Feb')
edf3= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2022.xlsx',sheet_name='March')
edf4= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2022.xlsx',sheet_name='April')
edf5= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2022.xlsx',sheet_name='May')
edf6= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2022.xlsx',sheet_name='June')
edf7= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2022.xlsx',sheet_name='July 1')
edf8= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2022.xlsx',sheet_name='July-2')
edf9= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2022.xlsx',sheet_name='Aug - 1')
edf10= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2022.xlsx',sheet_name='Aug - 2')
edf11= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2022.xlsx',sheet_name='Sept - 1')
edf12= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2022.xlsx',sheet_name='Sept - 2')
edf13= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2022.xlsx',sheet_name='Octo - 1')
edf14= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2022.xlsx',sheet_name='Oct - 2')
edf15= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2022.xlsx',sheet_name='Nov - 1')
edf16= pd.read_excel(r'D:\python massai\chace assesment\Rice Exporters 2022.xlsx',sheet_name='Nov - 2')

# %%
# merge whole data of year 2022 and creating one dataframe

dfs2022 = [edf1, edf2, edf3, edf4,edf5, edf6, edf7, edf8, edf9, edf10, edf11, edf12, edf13, edf14, edf15, edf16]
df_2022 = reduce(lambda left,right: pd.merge(left,right,how='outer'), dfs2022)
df_2022.shape
# Out:
# (104458, 46)

# %% [markdown]
# #### merge whole data of 5 years and creating one dataframe

# %%
 finaldf = [df_2018, df_2019, df_2020, df_2021,df_2022]
df = reduce(lambda left,right: pd.merge(left,right,how='outer'), finaldf)
df.shape
# Out:
# C:\Users\Aditya\AppData\Local\Temp\ipykernel_20516\1560238007.py:2: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation.
#   df = reduce(lambda left,right: pd.merge(left,right,how='outer'), finaldf)
# C:\Users\Aditya\AppData\Local\Temp\ipykernel_20516\1560238007.py:2: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation.
#   df = reduce(lambda left,right: pd.merge(left,right,how='outer'), finaldf)
# C:\Users\Aditya\AppData\Local\Temp\ipykernel_20516\1560238007.py:2: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation.
#   df = reduce(lambda left,right: pd.merge(left,right,how='outer'), finaldf)
# (428548, 48)

# %% [markdown]
# #### visualising data

# %%
df.head()
# Out:
#    NO        ARRIVAL DATE   HS CODE  \
# 0   1 2018-01-30 03:00:00  10063090
# 1   2 2018-01-30 03:00:00  10063090
# 2   3 2018-01-30 03:00:00  10063090
# 3   4 2018-01-30 03:00:00  10063010
# 4   5 2018-01-30 03:00:00  10063090
#
#                          HS CODE DESCRIPTION  \
# 0  Rice Excptg Parboiled (Excl Basmati Rice)
# 1  Rice Excptg Parboiled (Excl Basmati Rice)
# 2  Rice Excptg Parboiled (Excl Basmati Rice)
# 3                            Rice, parboiled
# 4  Rice Excptg Parboiled (Excl Basmati Rice)
#
#                          IMPORTER NAME IMPORTER ADDRESS      IMPORTER COUNTRY  \
# 0                 WALQ GENERAL TRADING                .  United Arab Emirates
# 1  FINE WAY INTERNATIONAL TRADING LLC.                .  United Arab Emirates
# 2                SEMMALAI TRADING LLC.                .  United Arab Emirates
# 3      INTEGRATED GREEN RESOURCES LLC.                .  United Arab Emirates
# ...

# %%
df.columns
# Out:
# Index(['ARRIVAL DATE', 'HS CODE', 'HS CODE DESCRIPTION', 'IMPORTER NAME',
#        'IMPORTER ADDRESS', 'IMPORTER COUNTRY', 'CITY STATE', 'EXPORTER NAME',
#        'EXPORTER ADDRESS', 'COUNTRY OF ORIGIN', 'IMPORT VALUE FOB',
#        'IMPORT VALUE CIF', 'CURRENCY', 'NET WEIGHT', 'NET WEIGHT UNIT',
#        'GROSS WEIGHT', 'GROSS WEIGHT UNIT', 'QUANTITY', 'QUANTITY UNIT',
#        'PRODUCT DETAILS', 'NUMBER OF PACKAGES', 'PACKAGES UNIT', 'INCOTERMS',
#        'PLACE OF DELIVERY', 'BRAND NAME', 'MANUFACTORING COMPANY',
#        'PORT OF ARRIVAL', 'PORT OF DEPARTURE', 'NOTIFY PARTY',
#        'NOTIFY ADDRESS', 'VOLUME', 'VOLUME UNIT', 'PREPORT', 'SHIPPER COUNTRY',
#        'US STATE', 'US PORT2', 'FINAL US PORT', 'FINAL FOREIGN PORT',
#        'FINAL COUNTRY', 'CONTAINER COUNT', 'TOTAL TEUS', 'Final Qty',
#        'PORT OF DEPARTURE.1'],
#       dtype='object')

# %% [markdown]
# #### checking columns with lot of null values or irrelavant columns

# %%
df['NUMBER OF PACKAGES'].value_counts()
# Out:
# 0.00         426071
# 5200.00         252
# 2600.00         136
# 1.00            101
# 10.00            73
#               ...
# 156.03            1
# 161.51            1
# 604.00            1
# 531940.00         1
# 165200.00         1
# Name: NUMBER OF PACKAGES, Length: 493, dtype: int64

# %% [markdown]
# #### Removing empty columns or irrelavant columns like serial number etc which does not play any role in calculation or analysis

# %%
df= df[['ARRIVAL DATE', 'HS CODE', 'HS CODE DESCRIPTION', 'IMPORTER NAME',
        'IMPORTER COUNTRY', 'CITY STATE','EXPORTER NAME', 'EXPORTER ADDRESS',
       'COUNTRY OF ORIGIN', 'IMPORT VALUE FOB','CURRENCY','QUANTITY', 'QUANTITY UNIT',
       'PRODUCT DETAILS','PORT OF ARRIVAL', 'PORT OF DEPARTURE']]

# %%
df.columns
# Out:
# Index(['ARRIVAL DATE', 'HS CODE', 'HS CODE DESCRIPTION', 'IMPORTER NAME',
#        'IMPORTER COUNTRY', 'CITY STATE', 'EXPORTER NAME', 'EXPORTER ADDRESS',
#        'COUNTRY OF ORIGIN', 'IMPORT VALUE FOB', 'CURRENCY', 'QUANTITY',
#        'QUANTITY UNIT', 'PRODUCT DETAILS', 'PORT OF ARRIVAL',
#        'PORT OF DEPARTURE'],
#       dtype='object')

# %% [markdown]
# #### Exporting excel file

# %%
 df.to_excel(r'D:\python massai\chace assesment\df.xlsx')

# %%
df= pd.read_excel(r'D:\python massai\chace assesment\df.xlsx')

# %%
df
# Out:
#         Unnamed: 0        ARRIVAL DATE     HS CODE  \
# 0                0 2018-01-30 03:00:00    10063090
# 1                1 2018-01-30 03:00:00    10063090
# 2                2 2018-01-30 03:00:00    10063090
# 3                3 2018-01-30 03:00:00    10063010
# 4                4 2018-01-30 03:00:00    10063090
# ...            ...                 ...         ...
# 428543      428543 2022-11-17 00:00:00  1006306709
# 428544      428544 2022-11-17 00:00:00    10063010
# 428545      428545 2022-11-17 00:00:00    10063020
# 428546      428546 2022-11-17 00:00:00    10063090
# 428547      428547 2022-11-17 00:00:00    10063099
#
#                                       HS CODE DESCRIPTION  \
# 0               Rice Excptg Parboiled (Excl Basmati Rice)
# 1               Rice Excptg Parboiled (Excl Basmati Rice)
# 2               Rice Excptg Parboiled (Excl Basmati Rice)
# 3                                         Rice, parboiled
# ...

# %% [markdown]
# #### How many distinct currencies are their

# %%
df['CURRENCY'].unique()
# Out:
# array(['USD', 'AUD', 'CAD', 'KES', 'INR', 'GBP', 'EUR', 'AED', 'LKR',
#        'SGD', 'MZN', 'XOF', nan, 'MDL', 'CHF', 'NZD', 'QAR', 'KWD', 'DKK',
#        'JPY', 'HKD', 'GHS', 'NGN', 'UGX', 'GHC', 'RUR', 'UAH', 'ZAR',
#        'TZS', 'ETB', 'FJD', 'RUB', 'KZT', 'SAR', 'SEK'], dtype=object)

# %% [markdown]
# #### Checking occurance of "CURRENCY" column

# %%
df['CURRENCY'].value_counts()
# Out:
# USD    317411
# INR     76326
# EUR      4773
# GBP      2770
# CAD      2488
# SGD      1971
# AUD      1887
# XOF      1824
# UGX      1807
# KES      1270
# MZN       895
# AED       770
# GHS       462
# CHF       144
# KZT        92
# NZD        87
# FJD        75
# ETB        75
# MDL        74
# LKR        64
# UAH        46
# HKD        27
# QAR        20
# ZAR        15
# GHC        13
# SAR         9
# JPY         7
# NGN         4
# RUR         2
# TZS         2
# KWD         2
# DKK         1
# RUB         1
# SEK         1
# Name: CURRENCY, dtype: int64

# %% [markdown]
# #### Assigning values of "Currency" on the basis of USD (for example 1 USD =  82.18 INR) with the help of dictionary

# %%
curr_dict ={'USD': 1,
 'AUD': 0.69,
 'CAD': 0.75,
 'KES': 0.008,
 'INR': 0.012,
 'GBP': 1.21,
 'EUR': 1.08,
 'AED': 0.27,
 'LKR': 0.0027,
 'SGD': 0.76,
 'MZN': 0.016,
 'XOF': 0.0017,
 'MDL': 0.053,
 'CHF': 1.08,
 'NZD': 0.63,
 'QAR': 0.27,
 'KWD': 3.28,
 'DKK': 0.15,
 'JPY': 0.0076,
 'HKD': 0.13,
 'GHS': 0.082,
 'NGN': 0.0022,
 'UGX': 0.00027,
 'GHC': 0.082,
 'RUR': 0.014,
 'ZAR': 0.057,
 'TZS': 0.00043,
 'ETB': 0.019,
 'FJD': 0.46,
 'RUB': 0.014,
 'SAR':0.27,
 'SEK': 0.095,
 'KZT': 0.0022}

# %% [markdown]
# #### Creating new column in df with the name of 'IMPORT VALUE FOB (USD)' and converting all values of "IMPORT VALUE FOB" column to USD

# %%
df['IMPORT VALUE FOB (USD)']=1
for i in df.index:
    b=df.iloc[i]['CURRENCY']
    # print(b)
    

    if b in curr_dict:
        df['IMPORT VALUE FOB (USD)'][i]=curr_dict[b]*df.iloc[i]['IMPORT VALUE FOB']
    else:
        df['IMPORT VALUE FOB (USD)'][i]
# Out:
# C:\Users\Aditya\AppData\Local\Temp\ipykernel_17192\1421278542.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['IMPORT VALUE FOB (USD)'][i]=curr_dict[b]*df.iloc[i]['IMPORT VALUE FOB']

# %%
df.head(2)
# Out:
#    Unnamed: 0        ARRIVAL DATE   HS CODE  \
# 0           0 2018-01-30 03:00:00  10063090
# 1           1 2018-01-30 03:00:00  10063090
#
#                          HS CODE DESCRIPTION  \
# 0  Rice Excptg Parboiled (Excl Basmati Rice)
# 1  Rice Excptg Parboiled (Excl Basmati Rice)
#
#                          IMPORTER NAME      IMPORTER COUNTRY  \
# 0                 WALQ GENERAL TRADING  United Arab Emirates
# 1  FINE WAY INTERNATIONAL TRADING LLC.  United Arab Emirates
#
#              CITY STATE                             EXPORTER NAME  \
# 0  United Arab Emirates  SCM AGROTECH ENTERPRISES PRIVATE LIMITED
# 1  United Arab Emirates   SRI RAMA MODERN & PARA BOILED RICE MILL
#
#                                     EXPORTER ADDRESS COUNTRY OF ORIGIN  \
# 0  165&166A,ZONE1-M.P NAGAR,   ,BHOPAL,MADHYA PRA...             India
# 1  SARANGAPUR VILLAGENIZAMABAD.   ,ANDHRA PRADESH...             India
#
#    IMPORT VALUE FOB CURRENCY  QUANTITY QUANTITY UNIT  \
# ...

# %% [markdown]
# #### Checking occurance of "Quantity unit" column for different units

# %%
df['QUANTITY UNIT'].value_counts()
# Out:
# MTS              210136
# KGS              101924
# NOS               26563
# QTL               14573
# BAG               12254
#                   ...
# PCK                   1
# UNIT (UNIDAD)         1
# TBS                   1
# CRT                   1
# INC                   1
# Name: QUANTITY UNIT, Length: 100, dtype: int64

# %% [markdown]
# #### checking total number of occurance for particular units

# %%
filter = df['QUANTITY UNIT']=='kg'
print(df.where(filter).count())
# Out:
# Unnamed: 0                1194
# ARRIVAL DATE              1194
# HS CODE                   1194
# HS CODE DESCRIPTION       1194
# IMPORTER NAME             1194
# IMPORTER COUNTRY          1194
# CITY STATE                1194
# EXPORTER NAME             1194
# EXPORTER ADDRESS          1191
# COUNTRY OF ORIGIN         1194
# IMPORT VALUE FOB          1194
# CURRENCY                  1194
# QUANTITY                  1194
# QUANTITY UNIT             1194
# PRODUCT DETAILS           1194
# PORT OF ARRIVAL           1194
# PORT OF DEPARTURE            0
# IMPORT VALUE FOB (USD)    1194
# dtype: int64

# %% [markdown]
# #### how many distinct measurement units are there

# %%
df['QUANTITY UNIT'].unique()
# Out:
# array(['MTS', 'KGS', 'NOS', 'PCS', 'kg', 'KGM', 'CTN', 'кг', 'BAG', nan,
#        'BOX', 'PAC', 'KG', 'Kg', 'PKG', 'TON', 'KILOGRAMOS NETOS', 'MTR',
#        'Kgm', 'KILOGRAMMES', 'QTL', 'BG', 'kilos', 'QUILOGRAMA LIQUIDO',
#        'Net kg', 'LOT', 'SQM', 'Kilogram', 'CRT', 'SET', 'Kilogramos',
#        'Tonelada', 'BGS', 'TONS', 'LBS', 'GMS', 'VPK', 'BUN', 'Kilo',
#        'TBN', 'BX', 'PCK', 'PK', 'CT', 'NET KG', 'PD', 'PX', 'TONELADA',
#        'ZB', 'Toneladas', 'SA', 'PIECE', 'Box (Caja)', 'TNE', 'CS',
#        'BAGS', 'PACKAGES', 'LTR', 'KILOGRAMO BRUTO', 'INC', 'TBS', 'DRM',
#        'KLR', 'UNK', 'KILOS', 'KILOGRAM', 'CAS', 'КГ', 'KGA', 'CARTONS',
#        'PACKAGE(S)', 'CTM', 'Kg.', 'MDW', 'BOXES', 'ШТ', 'Tons', 'PCE',
#        'SAC', 'BAGS  PLASTIC', 'PACKAGE / PARCEL', 'UNIT (UNIDAD)',
#        'KILO', 'PIECE(S)', 'KILOGRAMO', 'CONTAINER(S)  N.O.S.',
#        'PACKAGE  DISPLAY  WOODEN', 'PALLETS', 'PKGS', 'PACKAGE',
# ...

# %% [markdown]
# #### Assigning values of measuring units on the basis of kg (for example 1 ton = 1000 kg) with the help of dictionary

# %%
mass_dict={'kg':1,'KGS':1,'KG': 1,'Kg':1,'MTS':1000, 'BAG': 43,'NOS': 0.10197, 'PCS': 1.66, 'KGM': 1,'CTN': 10,'BAG': 42.637, 'TON':1000,
            'KILOGRAMOS NETOS':1000,'Kgm':1, 'KILOGRAMMES':1,'QTL':100,'kilos':1,'BG':43,'Net kg':1, 'LOT':0.0127,'Kilogram':1,'CRT':0.0002,
             'SET':6.4, 'Kilogramos':1, 'Tonelada': 1000, 'BGS':43, 'TONS':1000,'LBS': 0.454, 'GMS': 0.001, 'Kilo':1, 'TBN':907.18, 'BX':0.13,
             'PK':1, 'CT':0.0002, 'NET KG':1, 'PD':0.454, 'TONELADA':1000, 'Toneladas':1000, 'SA':3.24, 'TNE': 1000, 'BAGS': 43, 'LTR': 0.92,
             'KILOGRAMO BRUTO': 1, 'DRM': 0.468, 'KLR': 0.92, 'UNK': 1016, 'KILOS': 1, 'KILOGRAM': 1, 'KGA':1, 'CTM': 0.0002, 'Kg.': 1, 
              'Tons': 1000, 'KILO': 1, 'KILOGRAMO': 1
              }

# %%
len(mass_dict)
# Out:
# 53

# %% [markdown]
# #### Creating new column in df with the name of 'quantity_in_kg' and converting all values of quantity column to KG

# %%
df['quantity_in_kg']=1
for i in df.index:
    b=df.iloc[i]['QUANTITY UNIT']
    # print(b)
    

    if b in mass_dict:
        df['quantity_in_kg'][i]=mass_dict[b]*df.iloc[i]['QUANTITY']
    else:
        df['quantity_in_kg'][i]
# Out:
# C:\Users\Aditya\AppData\Local\Temp\ipykernel_17192\2794192235.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['quantity_in_kg'][i]=mass_dict[b]*df.iloc[i]['QUANTITY']

# %%
df.head(2)
# Out:
#    Unnamed: 0        ARRIVAL DATE   HS CODE  \
# 0           0 2018-01-30 03:00:00  10063090
# 1           1 2018-01-30 03:00:00  10063090
#
#                          HS CODE DESCRIPTION  \
# 0  Rice Excptg Parboiled (Excl Basmati Rice)
# 1  Rice Excptg Parboiled (Excl Basmati Rice)
#
#                          IMPORTER NAME      IMPORTER COUNTRY  \
# 0                 WALQ GENERAL TRADING  United Arab Emirates
# 1  FINE WAY INTERNATIONAL TRADING LLC.  United Arab Emirates
#
#              CITY STATE                             EXPORTER NAME  \
# 0  United Arab Emirates  SCM AGROTECH ENTERPRISES PRIVATE LIMITED
# 1  United Arab Emirates   SRI RAMA MODERN & PARA BOILED RICE MILL
#
#                                     EXPORTER ADDRESS COUNTRY OF ORIGIN  \
# 0  165&166A,ZONE1-M.P NAGAR,   ,BHOPAL,MADHYA PRA...             India
# 1  SARANGAPUR VILLAGENIZAMABAD.   ,ANDHRA PRADESH...             India
#
#    IMPORT VALUE FOB CURRENCY  QUANTITY QUANTITY UNIT  \
# ...

# %% [markdown]
# Checking null values

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                     0
# ARRIVAL DATE                   0
# HS CODE                        0
# HS CODE DESCRIPTION         2398
# IMPORTER NAME               2614
# IMPORTER COUNTRY               0
# CITY STATE                   187
# EXPORTER NAME               2024
# EXPORTER ADDRESS           31116
# COUNTRY OF ORIGIN              0
# IMPORT VALUE FOB               0
# CURRENCY                   13133
# QUANTITY                       0
# QUANTITY UNIT              20792
# PRODUCT DETAILS             5536
# PORT OF ARRIVAL            15852
# PORT OF DEPARTURE          28243
# IMPORT VALUE FOB IN USD        0
# IMPORT VALUE FOB (USD)         0
# quantity_in_kg                 0
# dtype: int64

# %% [markdown]
# ### Null values cant be replaced as nulls are in categorical columns and if you fill with mode then data would be tampered

# %% [markdown]
# #### Removing useless column of id

# %%
df= df.drop(columns='Unnamed: 0')

# %%
df.head(2)
# Out:
#          ARRIVAL DATE   HS CODE                        HS CODE DESCRIPTION  \
# 0 2018-01-30 03:00:00  10063090  Rice Excptg Parboiled (Excl Basmati Rice)
# 1 2018-01-30 03:00:00  10063090  Rice Excptg Parboiled (Excl Basmati Rice)
#
#                          IMPORTER NAME      IMPORTER COUNTRY  \
# 0                 WALQ GENERAL TRADING  United Arab Emirates
# 1  FINE WAY INTERNATIONAL TRADING LLC.  United Arab Emirates
#
#              CITY STATE                             EXPORTER NAME  \
# 0  United Arab Emirates  SCM AGROTECH ENTERPRISES PRIVATE LIMITED
# 1  United Arab Emirates   SRI RAMA MODERN & PARA BOILED RICE MILL
#
#                                     EXPORTER ADDRESS COUNTRY OF ORIGIN  \
# 0  165&166A,ZONE1-M.P NAGAR,   ,BHOPAL,MADHYA PRA...             India
# 1  SARANGAPUR VILLAGENIZAMABAD.   ,ANDHRA PRADESH...             India
#
#    IMPORT VALUE FOB CURRENCY  QUANTITY QUANTITY UNIT  \
# 0          25970.76      USD     50.04           MTS
# ...

# %% [markdown]
# #### Adding column of year to analyse on Yearly basis

# %%
df['year'] = pd.DatetimeIndex(df['ARRIVAL DATE']).year

# %%
df
# Out:
#               ARRIVAL DATE     HS CODE  \
# 0      2018-01-30 03:00:00    10063090
# 1      2018-01-30 03:00:00    10063090
# 2      2018-01-30 03:00:00    10063090
# 3      2018-01-30 03:00:00    10063010
# 4      2018-01-30 03:00:00    10063090
# ...                    ...         ...
# 428543 2022-11-17 00:00:00  1006306709
# 428544 2022-11-17 00:00:00    10063010
# 428545 2022-11-17 00:00:00    10063020
# 428546 2022-11-17 00:00:00    10063090
# 428547 2022-11-17 00:00:00    10063099
#
#                                       HS CODE DESCRIPTION  \
# 0               Rice Excptg Parboiled (Excl Basmati Rice)
# 1               Rice Excptg Parboiled (Excl Basmati Rice)
# 2               Rice Excptg Parboiled (Excl Basmati Rice)
# 3                                         Rice, parboiled
# 4               Rice Excptg Parboiled (Excl Basmati Rice)
# ...                                                   ...
# 428543  Rice, Semi-Milled Or Wholly Milled, Whether Or...
# ...

# %% [markdown]
# ### The top exporters in the last 5 years with the location they export to, total quantity exported, any other relevant data point you feel will be helpful

# %%
# Top 10 exporters in last 5 years
# group by 'EXPORTER NAME','IMPORTER COUNTRY' and ascending sum('IMPORT VALUE FOB IN USD') in descending order, sum of total quantity in kg
k = df[['EXPORTER NAME','IMPORTER COUNTRY','quantity_in_kg','IMPORT VALUE FOB (USD)']].groupby(['EXPORTER NAME','IMPORTER COUNTRY'])
k['quantity_in_kg','IMPORT VALUE FOB (USD)'].sum().sort_values(by=['IMPORT VALUE FOB (USD)'], ascending = [False]).head(10)
# Out:
# C:\Users\Aditya\AppData\Local\Temp\ipykernel_15828\915130597.py:4: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   k['quantity_in_kg','IMPORT VALUE FOB (USD)'].sum().sort_values(by=['IMPORT VALUE FOB (USD)'], ascending = [False]).head(10)
#                                                                      quantity_in_kg  \
# EXPORTER NAME                                      IMPORTER COUNTRY
# SUPPLE TEK INDUSTRIES PRIVATE LIMITED              Iran                1.459949e+09
# PJS OVERSEAS LIMITED                               Iran                1.686756e+08
# GRM OVERSEAS LIMITED                               Iran                3.870546e+08
# KHUSHI  RAM  DURGA   DASS                          Oman                1.357752e+06
# BHAGWATI LACTO VEGETARIAN EXPORTS PRIVATE LIMITED. Iran                6.707466e+07
# TANNA AGRO IMPEX PVT.LTD.                          Kuwait              2.918395e+08
# ...

# %%
df.columns
# Out:
# Index(['ARRIVAL DATE', 'HS CODE', 'HS CODE DESCRIPTION', 'IMPORTER NAME',
#        'IMPORTER COUNTRY', 'CITY STATE', 'EXPORTER NAME', 'EXPORTER ADDRESS',
#        'COUNTRY OF ORIGIN', 'IMPORT VALUE FOB', 'CURRENCY', 'QUANTITY',
#        'QUANTITY UNIT', 'PRODUCT DETAILS', 'PORT OF ARRIVAL',
#        'PORT OF DEPARTURE', 'IMPORT VALUE FOB (USD)', 'quantity_in_kg',
#        'year'],
#       dtype='object')

# %% [markdown]
# #### Year wise top to bottom import in terms of total value in USD

# %%
# With Respect to FOB value USD
kk = df[['IMPORT VALUE FOB (USD)', 'year']]  # filtring table 


# group by 'year','IMPORTER COUNTRY' and sum of ('IMPORT VALUE FOB IN USD') in descending order
kk.groupby(['year']).aggregate({'IMPORT VALUE FOB (USD)':'sum'}).sort_values(by=['IMPORT VALUE FOB (USD)'], ascending = [False])
# Out:
#       IMPORT VALUE FOB (USD)
# year
# 2021            5.443379e+09
# 2022            5.096859e+09
# 2018            4.432325e+09
# 2019            3.788552e+09
# 2020            3.168954e+09

# %% [markdown]
# #### Year wise top to bottom import in terms of total quantity in KG

# %%
# With Respect to total quantity in kg
kk = df[['quantity_in_kg', 'year']]  # filtring table 


# group by 'year' and sum of ('IMPORT VALUE FOB IN USD') in descending order
abc= kk.groupby(['year']).aggregate({'quantity_in_kg':'sum'}).sort_values(by=['quantity_in_kg'], ascending = [False])

# %%
df.columns
# Out:
# Index(['ARRIVAL DATE', 'HS CODE', 'HS CODE DESCRIPTION', 'IMPORTER NAME',
#        'IMPORTER COUNTRY', 'CITY STATE', 'EXPORTER NAME', 'EXPORTER ADDRESS',
#        'COUNTRY OF ORIGIN', 'IMPORT VALUE FOB', 'CURRENCY', 'QUANTITY',
#        'QUANTITY UNIT', 'PRODUCT DETAILS', 'PORT OF ARRIVAL',
#        'PORT OF DEPARTURE', 'IMPORT VALUE FOB (USD)', 'quantity_in_kg',
#        'year'],
#       dtype='object')

# %% [markdown]
# ### The top importers and country

# %%
# With Respect to FOB value and 'Quantity'

# top five
# group by 'EXPORTER NAME','IMPORTER COUNTRY' and ascending sum('IMPORT VALUE FOB IN USD') in descending order
df.groupby(['IMPORTER NAME','IMPORTER COUNTRY']).aggregate({'quantity_in_kg':'sum','IMPORT VALUE FOB (USD)':'sum'}).sort_values(by=['IMPORT VALUE FOB (USD)'], ascending = [False]).head(5)
# Out:
#                                                     quantity_in_kg  \
# IMPORTER NAME                     IMPORTER COUNTRY
# ABDULRAHMAN & MOHD, A AZIZ        Saudi Arabia        4.841254e+08
# GOVERNMENT TRADING CORP. OF I     Iran                1.442265e+08
# DIAMOND GRAINS TRADING LLC.       Somalia             9.386533e+08
# TABIAT SABZ MIHAN                 Iran                2.505386e+08
# TABIAT SABZ PARS KOHAN NO.O,NORTH Iran                2.445292e+08
#
#                                                     IMPORT VALUE FOB (USD)
# IMPORTER NAME                     IMPORTER COUNTRY
# ABDULRAHMAN & MOHD, A AZIZ        Saudi Arabia                4.210495e+08
# GOVERNMENT TRADING CORP. OF I     Iran                        3.344531e+08
# DIAMOND GRAINS TRADING LLC.       Somalia                     3.269259e+08
# TABIAT SABZ MIHAN                 Iran                        2.716911e+08
# TABIAT SABZ PARS KOHAN NO.O,NORTH Iran                        2.465037e+08

# %% [markdown]
# ### The top port's for rice exports

# %%
# Top 5 ports with respect to quantity

df.groupby(['PORT OF DEPARTURE']).aggregate({'quantity_in_kg':'sum'}).sort_values(by=['quantity_in_kg'], ascending = [False]).head(5)
# Out:
#                      quantity_in_kg
# PORT OF DEPARTURE
# MUNDRA SEA (INMUN1)    6.574122e+09
# AMBERES                5.663804e+09
# KANDLA SEA (INIXY1)    4.284152e+09
# VIZAG SEA (INVTZ1)     1.480483e+09
# Mundra SEA (INMUN1)    1.332076e+09

# %%
# Importing Libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### The trend of rice exporters over time

# %%
# 5 year trend on the basis of Quantity
plt.figure(figsize=(10,6))
sns.barplot(data= df, x='year', y= 'quantity_in_kg')
# Out:
# <AxesSubplot: xlabel='year', ylabel='quantity_in_kg'>

# %%
# 5 year trend on the basis of Value USD
plt.figure(figsize=(10,6))
sns.barplot(data= df, x='year', y= 'IMPORT VALUE FOB (USD)')
# Out:
# <AxesSubplot: xlabel='year', ylabel='IMPORT VALUE FOB (USD)'>

# %% [markdown]
# ### Any other insights you may find interesting or relevant

# %%
df.head()
# Out:
#          ARRIVAL DATE   HS CODE                        HS CODE DESCRIPTION  \
# 0 2018-01-30 03:00:00  10063090  Rice Excptg Parboiled (Excl Basmati Rice)
# 1 2018-01-30 03:00:00  10063090  Rice Excptg Parboiled (Excl Basmati Rice)
# 2 2018-01-30 03:00:00  10063090  Rice Excptg Parboiled (Excl Basmati Rice)
# 3 2018-01-30 03:00:00  10063010                            Rice, parboiled
# 4 2018-01-30 03:00:00  10063090  Rice Excptg Parboiled (Excl Basmati Rice)
#
#                          IMPORTER NAME      IMPORTER COUNTRY  \
# 0                 WALQ GENERAL TRADING  United Arab Emirates
# 1  FINE WAY INTERNATIONAL TRADING LLC.  United Arab Emirates
# 2                SEMMALAI TRADING LLC.  United Arab Emirates
# 3      INTEGRATED GREEN RESOURCES LLC.  United Arab Emirates
# 4             GBR GENERAL TRADING FZC.  United Arab Emirates
#
#              CITY STATE                             EXPORTER NAME  \
# 0  United Arab Emirates  SCM AGROTECH ENTERPRISES PRIVATE LIMITED
# ...

# %% [markdown]
# #### Top 10 most sold rice type on the basis of quantity sold in KG

# %%
df.groupby(['PRODUCT DETAILS']).aggregate({'quantity_in_kg':'sum'}).sort_values(by=['quantity_in_kg'], ascending = [False]).head(10)
# Out:
#                                                     quantity_in_kg
# PRODUCT DETAILS
# ARROZ GRANO LARGO BLANCO,USO: CONSUMO,PORCENTAJ...    1.040000e+09
# ARROZ  BLANCO PULIDO,GRANO LARGO,MAXIMO 5 POR C...    9.100000e+08
# NON BASMATI RICE                                      8.168451e+08
# ARROZ PULIDO,USO: CONSUMO,PORCENTAJE GRANOPARTI...    7.800000e+08
# ARROZ PULIDO,USO: CONSUMO,PORCENTAJE GRANO PART...    7.800000e+08
# INDIAN PARBOILED RICE CLEAN AND SORTEX NON BASMATI    5.300000e+08
# ARROZ,SEMIBLANQUEADO,ALIMENTO PARBOILED CONTENI...    5.200000e+08
# GẠO ĐỒ- NLSX TACN HÀNG PHÙ HỢP TT 21/2019/TT- B...    5.200000e+08
# INDIAN NON BASMATI PARBOILED RICE PACKED              4.659685e+08
# SONA MASOORI SONA MASOORI RICE 1X10KG/25KG BAGS       3.873546e+08

# %% [markdown]
# #### Chile import highest rice followed by iran and saudi
# on the basis of quantity in kg

# %%
df.groupby(['IMPORTER COUNTRY']).aggregate({'quantity_in_kg':'sum'}).sort_values(by=['quantity_in_kg'], ascending = [False]).head(10)
# Out:
#                       quantity_in_kg
# IMPORTER COUNTRY
# Chile                   9.649919e+09
# Iran                    3.832502e+09
# Saudi Arabia            2.247236e+09
# Bangladesh              2.242428e+09
# South Sudan             2.032952e+09
# Iraq                    1.746047e+09
# United Arab Emirates    1.667037e+09
# Benin                   1.301660e+09
# Viet Nam                1.265856e+09
# Somalia                 1.188569e+09

# %% [markdown]
# #### Top Importer Countries In terms of quantity

# %%
dg = df[['IMPORTER COUNTRY','quantity_in_kg']].groupby('IMPORTER COUNTRY').aggregate({'quantity_in_kg':'sum'}) # group by year aggretion by IMPORT VALUE FOB IN USD'

dg = dg.sort_values(by='quantity_in_kg', ascending=False).head(10).reset_index() 

dg['Percentage'] = round(dg['quantity_in_kg']/sum(df['quantity_in_kg'])*100,2)  # by Percentage

# %%
dg = dg[['IMPORTER COUNTRY','Percentage']]

dg.loc[len(dg.index)] =['other',round(100-sum(dg['Percentage']),2)] # Inserting row named "Other"
dg
# Out:
#         IMPORTER COUNTRY  Percentage
# 0                  Chile       21.75
# 1                   Iran        8.64
# 2           Saudi Arabia        5.07
# 3             Bangladesh        5.05
# 4            South Sudan        4.58
# 5                   Iraq        3.94
# 6   United Arab Emirates        3.76
# 7                  Benin        2.93
# 8               Viet Nam        2.85
# 9                Somalia        2.68
# 10                 other       38.75

# %% [markdown]
# #### Pie chart of above analysis

# %%
import matplotlib.pyplot as plt
pie_chart = plt.pie(dg["Percentage"], labels = dg["IMPORTER COUNTRY"],autopct='%1.0f%%')
plt.title('Top Importer Countries on basis of quantity in kg')
plt.show()
